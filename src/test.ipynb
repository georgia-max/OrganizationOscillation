# %%
import pysd 
import pandas as pd
import netCDF4
import matplotlib.pyplot as plt
import seaborn as sns 


from pathlib import Path
import numpy as np
from scipy import stats

# %%
model = pysd.read_vensim("../Vensimmodel/pinknoise_test.mdl")

# %%
m1['TIME STEP']
# Out:
# 0.0000     0.0625
# 0.0625     0.0625
# 0.1250     0.0625
# 0.1875     0.0625
# 0.2500     0.0625
#             ...
# 49.7500    0.0625
# 49.8125    0.0625
# 49.8750    0.0625
# 49.9375    0.0625
# 50.0000    0.0625
# Name: TIME STEP, Length: 801, dtype: float64

# %%
print(pysd.__version__)
# Out:
# 3.9.1

# %%
m1 = model.run()

m1['TIME STEP']
m1['pink noise'].plot()
# Out:
# <Axes: >

# %%
a, b = 0.1, 2
# r = stats.truncnorm.rvs(a, b, size=1000)

r = stats.truncnorm.rvs(-6, 6, loc=0, scale=1, size = 50,  random_state=8)
plt.plot(r)
