# %% [markdown]
# # Organizational Oscillation V1
#
# This notebook runs the PySD model. It runs the vensim .mdl model
#
# Last Update: 11/13/2023
# Author: @georgia-max

# %%
import pysd 
import pandas as pd
import netCDF4
import matplotlib.pyplot as plt

# %%
# model = pysd.read_vensim("../Vensimmodel/Organizational_oscillation.mdl")
model = pysd.load('../Vensimmodel/Organizational_oscillation.py')

# %%
condition = {'Pulse start time': 0, 'Pulse end time': 10, 'Pulse Quantity': 0.1, 'Pulse duration': 0}

m1 = model.run(params= condition)

m1['Safety focus'].plot()
m1['NonSafety Focus'].plot()
m1['Safety Threshold'].plot()

plt.title("Organizational Oscillation") 
# plt.ylim(-1000, 1000)

plt.ylabel("mdl")
plt.xlabel("Time")
plt.legend()
plt.grid()

# %%
# model.doc
condition = {'Pulse start time': 0, 'Pulse end time': 30, 'Pulse Quantity': 5, 'Pulse duration': 1, 'Pulse Time': 5}

m2 = model.run(params = condition)

m2['Safety focus'].plot()
m2['NonSafety Focus'].plot()
m2['Safety Threshold'].plot()

plt.title("Organizational Oscillation") 
plt.ylim(-1000, 1000)
plt.ylabel("mdl")
plt.xlabel("Time")
plt.legend()
plt.grid()

# plt.title("Safety focus")
# plt.ylabel("mdl")
# plt.xlabel("Time")
# plt.grid()

# %%
condition = {'Pulse start time': 1, 'Pulse end time': 0, 'Pulse Quantity 1': 5, 'Pulse duration': 2, 'Pulse repeat time': 5, 'Pulse Time':  5}

m3 = model.run(params= condition)

m3['Safety focus'].plot()
m3['NonSafety Focus'].plot()
m3['Safety Threshold'].plot()

plt.title("Organizational Oscillation") 
plt.ylabel("mdl")
plt.xlabel("Time")
plt.ylim(-1500, 1500)

plt.legend()
plt.grid()

# %%
m1['Safety focus'].plot(label = 'm1')
m2['Safety focus'].plot(label = 'm2')
m3['Safety focus'].plot(label = 'm3')

plt.title("Safety focus")
plt.ylabel("mdl")
plt.xlabel("Time")
plt.grid()
plt.legend()
plt.show()

# %%
condition = {'Pulse start time': 0, 'Pulse end time': 10, 'Pulse Quantity 1': 0.1, 'Pulse duration': 1, 'Pulse Time': 5}

m1 = model.run(params= condition)

m1['Safety focus'].plot()
m1['NonSafety Focus'].plot()
m1['Safety Threshold'].plot()

plt.title("Organizational Oscillation") 
plt.ylabel("mdl")
plt.xlabel("Time")
plt.legend()
plt.grid()

# %%
pd.set_option('display.max_columns', None)
stocks
# Out:
#       FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  Pulse Quantity 1  \
# 0.0           30             0      0.5        0.5                 0
# 0.5           30             0      0.5        0.5                 0
# 1.0           30             0      0.5        0.5                 0
# 1.5           30             0      0.5        0.5                 0
# 2.0           30             0      0.5        0.5                 0
# ...          ...           ...      ...        ...               ...
# 28.0          30             0      0.5        0.5                 0
# 28.5          30             0      0.5        0.5                 0
# 29.0          30             0      0.5        0.5                 0
# 29.5          30             0      0.5        0.5                 0
# 30.0          30             0      0.5        0.5                 0
#
#       Pulse repeat time  Pulse end time  Pulse start time  input  \
# 0.0                   3              30                 0   12.0
# 0.5                   3              30                 0   12.0
# 1.0                   3              30                 0    2.0
# 1.5                   3              30                 0    2.0
# 2.0                   3              30                 0    2.0
# ...                 ...             ...               ...    ...
# 28.0                  3              30                 0    2.0
# 28.5                  3              30                 0    2.0
# 29.0                  3              30                 0    2.0
# 29.5                  3              30                 0    2.0
# 30.0                  3              30                 0    2.0
#
#       Pulse Duration  Safety Threshold  Ramp End Time  Ramp Slope  \
# 0.0                1             600.0              0           0
# 0.5                1             600.0              0           0
# 1.0                1             100.0              0           0
# 1.5                1             100.0              0           0
# 2.0                1             100.0              0           0
# ...              ...               ...            ...         ...
# 28.0               1             100.0              0           0
# 28.5               1             100.0              0           0
# 29.0               1             100.0              0           0
# 29.5               1             100.0              0           0
# 30.0               1             100.0              0           0
#
#       Ramp Start Time  initial Safety Threshold  Step Height  Pulse Quantity  \
# 0.0                 0                        50            1               5
# 0.5                 0                        50            1               5
# 1.0                 0                        50            1               5
# 1.5                 0                        50            1               5
# 2.0                 0                        50            1               5
# ...               ...                       ...          ...             ...
# 28.0                0                        50            1               5
# 28.5                0                        50            1               5
# 29.0                0                        50            1               5
# 29.5                0                        50            1               5
# 30.0                0                        50            1               5
#
#       Pulse Time  Step Time  NonSafety Focus  NonSafety foci forgetting rate  \
# 0.0            5          0         0.000000                               1
# 0.5            5          0        -5.000000                               1
# 1.0            5          0        19.750000                               1
# 1.5            5          0        74.500000                               1
# 2.0            5          0       133.012500                               1
# ...          ...        ...              ...                             ...
# 28.0           5          0      -812.846589                               1
# 28.5           5          0      -806.582500                               1
# 29.0           5          0      -754.926083                               1
# 29.5           5          0      -658.190540                               1
# 30.0           5          0      -518.958693                               1
#
#       NonSafety foci learning rate  Time to adjust focus  \
# 0.0                      -9.000000                     5
# 0.5                      50.500000                     5
# 1.0                     110.500000                     5
# 1.5                     118.025000                     5
# 2.0                     120.075000                     5
# ...                            ...                   ...
# 28.0                     13.528177                     5
# 28.5                    104.312836                     5
# 29.0                    194.471086                     5
# 29.5                    279.463694                     5
# 30.0                    354.782748                     5
#
#       Acceptable Safety performance  Safety Performance  Safety focus  \
# 0.0                              10           -9.000000      1.000000
# 0.5                              10           50.500000     60.500000
# 1.0                              10          110.500000    120.500000
# 1.5                              10          118.025000    128.025000
# 2.0                              10          120.075000    130.075000
# ...                             ...                 ...           ...
# 28.0                             10           13.528177     23.528177
# 28.5                             10          104.312836    114.312836
# 29.0                             10          194.471086    204.471086
# 29.5                             10          279.463694    289.463694
# 30.0                             10          354.782748    364.782748
#
#       Safety forgetting rate  Safety Learning rate  Safety Tolerance
# 0.0                        1            120.000000        120.000000
# 0.5                        1            121.000000        121.000000
# 1.0                        1             16.050000         16.050000
# 1.5                        1              5.100000          5.100000
# 2.0                        1             -6.602500         -6.602500
# ...                      ...                   ...               ...
# 28.0                       1            182.569318        182.569318
# 28.5                       1            181.316500        181.316500
# 29.0                       1            170.985217        170.985217
# 29.5                       1            151.638108        151.638108
# 30.0                       1            123.791739        123.791739
#
# [61 rows x 29 columns]

# %% [markdown]
# # Test 1. Time to adjust focus
#
# Testing different time to adjust focus. According to XX, management style effects the timing the organization deals with adjusting to safety focus. The shorter the time to adjust focus, the faster the organization adapts.
#
# - Hypothesis: the longer it took to adjust focus, the longer the cycle runs.
# - Condition: There is a pulse at time 5, with a duration of 1.
# - Parameter: Time to adjust focus = [5, 10, 15]
# - Result:

# %%
fig, ax = plt.subplots(figsize=(6,4))


# condition = {'Pulse start time': 0, 'Pulse end time': 10, 'Pulse Quantity': 0.1, 'Pulse duration': 0, 'Time to adjust focus': 5}
condition = {'Pulse start time': 1, 'Pulse end time': 0, 'Pulse Quantity 1': 1, 'Pulse duration': 1, 'Pulse repeat time': 5, 'Pulse Time':  10, 'Time to adjust focus': 5}

m1 = model.run(params= condition)
m1['Safety Threshold'].plot(label = 'Input')

m1['Safety focus'].plot(label = 'time to adjust focus = 5')

condition = {'Pulse start time': 1, 'Pulse end time': 0, 'Pulse Quantity 1': 1, 'Pulse duration': 1, 'Pulse repeat time': 5, 'Pulse Time':  10, 'Time to adjust focus': 10}

# condition = {'Pulse start time': 0, 'Pulse end time': 10, 'Pulse Quantity': 0.1, 'Pulse duration': 0, 'Time to adjust focus': 10}
m2 = model.run(params= condition)
m2['Safety focus'].plot(label = 'time to adjust focus = 10')
# m2['Safety Threshold'].plot()

condition = {'Pulse start time': 1, 'Pulse end time': 0, 'Pulse Quantity 1': 1, 'Pulse duration': 1, 'Pulse repeat time': 5, 'Pulse Time':  10, 'Time to adjust focus': 15}
m3 = model.run(params= condition)
m3['Safety focus'].plot(label = 'time to adjust focus = 15')
# m3['Safety Threshold'].plot()


# condition = {'Pulse start time': 0, 'Pulse end time': 10, 'Pulse Quantity': 0.1, 'Pulse duration': 0, 'Time to adjust focus': 20}
# m4 = model.run(params= condition)
# m4['Safety focus'].plot(label = 'time to adjust focus = 20')
# # m4['Safety Threshold'].plot()

plt.title("Safety Focus ") 
plt.ylabel("Level of Safety Focus")
plt.xlabel("Time")
# plt.ylim(-1000, 1000)

plt.legend()
plt.grid()

# Add a footnote below and to the right side of the chart
ax.annotate('Pulse duration =1, Pulse Time = 5',
            xy = (1.0, -0.2),
            xycoords='axes fraction',
            ha='right',
            va="center",
            fontsize=10)



plt.show()

# %% [markdown]
# # Test 2. magnitude of the error incident.
#
# Testing different magnitude of the incident. According to XX, the larger the safety incident (Pulse Quantity), the longer the cycle.
#
# - Hypothesis: the larger the safety incident (Pulse Quantity), the larger the cycle time
# - Condition: There is a pulse at time 5, with a duration of 1.
# - Result: Confirm
#
# #TODO find reference literature on the magnitude of the error incident.

# %%
fig, ax = plt.subplots(figsize=(8,5))


condition = {'Pulse start time': 0, 'Pulse end time': 10, 'Pulse Quantity': 0.1, 'Pulse duration': 0}

m1 = model.run(params= condition)

m1['Safety focus'].plot(label = 'base')
# m1['Safety Threshold'].plot()


condition = {'Pulse start time': 1, 'Pulse end time': 0, 'Pulse Quantity 1': 5, 'Pulse duration': 1, 'Pulse repeat time': 5, 'Pulse Time':  5}
m2 = model.run(params= condition)
m2['Safety focus'].plot(label = 'Pulse = 5')
# m2['Safety Threshold'].plot()

condition = {'Pulse start time': 1, 'Pulse end time': 0, 'Pulse Quantity 1': 10, 'Pulse duration': 1, 'Pulse repeat time': 5, 'Pulse Time':  5}
m3 = model.run(params= condition)
m3['Safety focus'].plot(label = 'Pulse = 10')
# m3['Safety Threshold'].plot()


condition = {'Pulse start time': 1, 'Pulse end time': 0, 'Pulse Quantity 1': 15, 'Pulse duration': 1, 'Pulse repeat time': 5, 'Pulse Time':  5}
m4 = model.run(params= condition)
m4['Safety focus'].plot(label = 'Pulse = 15')
# m4['Safety Threshold'].plot()

plt.title("Safety Focus ") 
plt.ylabel("Level of Safety Focus")
plt.xlabel("Time")
# plt.ylim(-1000, 1000)

plt.legend()
plt.grid()

# Add a footnote below and to the right side of the chart
ax.annotate('Pulse duration =1, Pulse Time = 5',
            xy = (1.0, -0.2),
            xycoords='axes fraction',
            ha='right',
            va="center",
            fontsize=10)



plt.show()

# %%
model.doc
# Out:
#                          Real Name                         Py Name Subscripts  \
# 0    Acceptable Safety performance   acceptable_safety_performance       None
# 1                       FINAL TIME                      final_time       None
# 2                     INITIAL TIME                    initial_time       None
# 3                  NonSafety Focus                 nonsafety_focus       None
# 4   NonSafety foci forgetting rate  nonsafety_foci_forgetting_rate       None
# 5     NonSafety foci learning rate    nonsafety_foci_learning_rate       None
# 6                   Pulse Duration                  pulse_duration       None
# 7                   Pulse Quantity                  pulse_quantity       None
# 8                 Pulse Quantity 1                pulse_quantity_1       None
# 9                       Pulse Time                      pulse_time       None
# 10                  Pulse end time                  pulse_end_time       None
# 11               Pulse repeat time               pulse_repeat_time       None
# 12                Pulse start time                pulse_start_time       None
# 13                   Ramp End Time                   ramp_end_time       None
# 14                      Ramp Slope                      ramp_slope       None
# 15                 Ramp Start Time                 ramp_start_time       None
# 16                         SAVEPER                         saveper       None
# 17            Safety Learning rate            safety_learning_rate       None
# 18              Safety Performance              safety_performance       None
# 19                Safety Threshold                safety_threshold       None
# 20                Safety Tolerance                safety_tolerance       None
# 21                    Safety focus                    safety_focus       None
# 22          Safety forgetting rate          safety_forgetting_rate       None
# 23                     Step Height                     step_height       None
# 24                       Step Time                       step_time       None
# 25                       TIME STEP                       time_step       None
# 26                            Time                            time       None
# 27            Time to adjust focus            time_to_adjust_focus       None
# 28        initial Safety Threshold        initial_safety_threshold       None
# 29                           input                         input_1       None
#
#    Units            Limits       Type Subtype  \
# 0   None        (nan, nan)   Constant  Normal
# 1   Year        (nan, nan)   Constant  Normal
# 2   Year        (nan, nan)   Constant  Normal
# 3   None        (nan, nan)   Stateful   Integ
# 4   None        (nan, nan)   Constant  Normal
# 5   None        (nan, nan)  Auxiliary  Normal
# 6   None        (nan, nan)   Constant  Normal
# 7   None        (nan, nan)   Constant  Normal
# 8   None        (nan, nan)   Constant  Normal
# 9   None        (nan, nan)   Constant  Normal
# 10  None        (nan, nan)   Constant  Normal
# 11  None        (nan, nan)   Constant  Normal
# 12  None        (nan, nan)   Constant  Normal
# 13  None        (nan, nan)   Constant  Normal
# 14  None        (nan, nan)   Constant  Normal
# 15  None        (nan, nan)   Constant  Normal
# 16  Year        (0.0, nan)  Auxiliary  Normal
# 17  None        (nan, nan)  Auxiliary  Normal
# 18  None        (nan, nan)  Auxiliary  Normal
# 19  None        (0.0, nan)  Auxiliary  Normal
# 20  None        (nan, nan)  Auxiliary  Normal
# 21  None        (nan, nan)   Stateful   Integ
# 22  None        (nan, nan)   Constant  Normal
# 23  None        (nan, nan)   Constant  Normal
# 24  None        (nan, nan)   Constant  Normal
# 25  Year        (0.0, nan)   Constant  Normal
# 26  None        (nan, nan)       None    None
# 27  None  (0.0, 20.0, 2.0)   Constant  Normal
# 28  None        (nan, nan)   Constant  Normal
# 29  None        (nan, nan)  Auxiliary  Normal
#
#                                        Comment
# 0                                         None
# 1           The final time for the simulation.
# 2         The initial time for the simulation.
# 3                                         None
# 4                                         None
# 5                                         None
# 6                                         None
# 7                                         None
# 8                                         None
# 9                                         None
# 10                                        None
# 11                                        None
# 12                                        None
# 13                                        None
# 14                                        None
# 15                                        None
# 16  The frequency with which output is stored.
# 17                                        None
# 18                                        None
# 19                                        None
# 20                                        None
# 21                                        None
# 22                                        None
# 23                                        None
# 24                                        None
# 25           The time step for the simulation.
# 26                  Current time of the model.
# 27                                        None
# 28                                        None
# 29                                        None

# %%
stocks['Time to adjust focus']
# Out:
# 0.0     5
# 0.5     5
# 1.0     5
# 1.5     5
# 2.0     5
#        ..
# 28.0    5
# 28.5    5
# 29.0    5
# 29.5    5
# 30.0    5
# Name: Time to adjust focus, Length: 61, dtype: int64

# %%
list(stocks.columns)
# Out:
# ['FINAL TIME',
#  'INITIAL TIME',
#  'SAVEPER',
#  'TIME STEP',
#  'Pulse Quantity 1',
#  'Pulse repeat time',
#  'Pulse end time',
#  'Pulse start time',
#  'input',
#  'Pulse Duration',
#  'Safety Threshold',
#  'Ramp End Time',
#  'Ramp Slope',
#  'Ramp Start Time',
#  'initial Safety Threshold',
#  'Step Height',
#  'Pulse Quantity',
#  'Pulse Time',
#  'Step Time',
#  'NonSafety Focus',
#  'NonSafety foci forgetting rate',
#  'NonSafety foci learning rate',
#  'Time to adjust focus',
#  'Acceptable Safety performance',
#  'Safety Performance',
#  'Safety focus',
#  'Safety forgetting rate',
#  'Safety Learning rate',
#  'Safety Tolerance']
