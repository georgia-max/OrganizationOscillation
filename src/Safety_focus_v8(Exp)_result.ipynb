# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
import pysd

# %% [markdown]
# # Pulse test results

# %%
df_pulse_high = pd.read_excel('../Experiment/Pulse_high.xlsx')

df_pulse_high = df_pulse_high.transpose()
# Set the first row as column names
df_pulse_high.columns = df_pulse_high.iloc[0]

# Drop the first row
df_pulse_high = df_pulse_high.drop(df_pulse_high.index[0])

df_pulse_high = df_pulse_high.astype(float)
df_pulse_high.head()
# Out:
# Time    attention capability  Attention erosion  Attention growth  \
# 0                       10.0           0.029105               0.0
# 0.0625                   NaN           0.028923               0.0
# 0.125                    NaN           0.028742               0.0
# 0.1875                   NaN           0.028562               0.0
# 0.25                     NaN           0.028384               0.0
#
# Time    Attention on Safety  Attention Resource  Chance of Errors  \
# 0                  0.110117            0.291046          0.094958
# 0.0625             0.108348            0.289227          0.095015
# 0.125              0.106614            0.287419          0.095072
# 0.1875             0.104915            0.285623          0.095129
# 0.25               0.103250            0.283838          0.095185
#
# Time    depreciation  desired attention goal  Error Occurance  \
# 0           0.019266                     1.0              0.0
# 0.0625      0.019379                     NaN              0.0
# 0.125       0.019483                     NaN              0.0
# 0.1875      0.019580                     NaN              0.0
# 0.25        0.019668                     NaN              0.0
#
# Time    exogenous shock  ...  pressure from manager  Safety threshold  \
# 0                   0.0  ...                   10.0               0.5
# 0.0625              0.0  ...                    NaN               NaN
# 0.125               0.0  ...                    NaN               NaN
# 0.1875              0.0  ...                    NaN               NaN
# 0.25                0.0  ...                    NaN               NaN
#
# Time    SAVEPER  seed  SWTICH  T to depreciate  T to gain experience  \
# 0        0.0625   1.0     1.0              5.0                  10.0
# 0.0625   0.0625   NaN     NaN              NaN                   NaN
# 0.125    0.0625   NaN     NaN              NaN                   NaN
# 0.1875   0.0625   NaN     NaN              NaN                   NaN
# 0.25     0.0625   NaN     NaN              NaN                   NaN
#
# Time    T to grow attention  T to lose attention  TIME STEP
# 0                       1.0                 10.0     0.0625
# 0.0625                  NaN                  NaN        NaN
# 0.125                   NaN                  NaN        NaN
# 0.1875                  NaN                  NaN        NaN
# 0.25                    NaN                  NaN        NaN
#
# [5 rows x 29 columns]

# %%
df_pulse_low = pd.read_excel('../Experiment/Pulse_low.xlsx')

df_pulse_low = df_pulse_low.transpose()
# Set the first row as column names
df_pulse_low.columns = df_pulse_low.iloc[0]

# Drop the first row
df_pulse_low = df_pulse_low.drop(df_pulse_low.index[0])

df_pulse_low = df_pulse_low.astype(float)
df_pulse_low.head()
# Out:
# Time    attention capability  Attention erosion  Attention growth  \
# 0                       10.0           0.029105               0.0
# 0.0625                   NaN           0.028923               0.0
# 0.125                    NaN           0.028742               0.0
# 0.1875                   NaN           0.028562               0.0
# 0.25                     NaN           0.028384               0.0
#
# Time    Attention on Safety  Attention Resource  Chance of Errors  \
# 0                  0.110117            0.291046          0.094958
# 0.0625             0.108348            0.289227          0.095015
# 0.125              0.106614            0.287419          0.095072
# 0.1875             0.104915            0.285623          0.095129
# 0.25               0.103250            0.283838          0.095185
#
# Time    depreciation  desired attention goal  Error Occurance  \
# 0           0.019266                     1.0              0.0
# 0.0625      0.019379                     NaN              0.0
# 0.125       0.019483                     NaN              0.0
# 0.1875      0.019580                     NaN              0.0
# 0.25        0.019668                     NaN              0.0
#
# Time    exogenous shock  ...  pressure from manager  Safety threshold  \
# 0                   0.0  ...                   10.0               0.5
# 0.0625              0.0  ...                    NaN               NaN
# 0.125               0.0  ...                    NaN               NaN
# 0.1875              0.0  ...                    NaN               NaN
# 0.25                0.0  ...                    NaN               NaN
#
# Time    SAVEPER  seed  SWTICH  T to depreciate  T to gain experience  \
# 0        0.0625   1.0     1.0              5.0                  10.0
# 0.0625   0.0625   NaN     NaN              NaN                   NaN
# 0.125    0.0625   NaN     NaN              NaN                   NaN
# 0.1875   0.0625   NaN     NaN              NaN                   NaN
# 0.25     0.0625   NaN     NaN              NaN                   NaN
#
# Time    T to grow attention  T to lose attention  TIME STEP
# 0                       1.0                 10.0     0.0625
# 0.0625                  NaN                  NaN        NaN
# 0.125                   NaN                  NaN        NaN
# 0.1875                  NaN                  NaN        NaN
# 0.25                    NaN                  NaN        NaN
#
# [5 rows x 29 columns]

# %%
df_pulse_med = pd.read_excel('../Experiment/Pulse_medium.xlsx')

df_pulse_med = df_pulse_med.transpose()
# Set the first row as column names
df_pulse_med.columns = df_pulse_med.iloc[0]

# Drop the first row
df_pulse_med = df_pulse_med.drop(df_pulse_med.index[0])

df_pulse_med = df_pulse_med.astype(float)
df_pulse_med.head()
# Out:
# Time    attention capability  Attention erosion  Attention growth  \
# 0                       10.0           0.029105               0.0
# 0.0625                   NaN           0.028923               0.0
# 0.125                    NaN           0.028742               0.0
# 0.1875                   NaN           0.028562               0.0
# 0.25                     NaN           0.028384               0.0
#
# Time    Attention on Safety  Attention Resource  Chance of Errors  \
# 0                  0.110117            0.291046          0.094958
# 0.0625             0.108348            0.289227          0.095015
# 0.125              0.106614            0.287419          0.095072
# 0.1875             0.104915            0.285623          0.095129
# 0.25               0.103250            0.283838          0.095185
#
# Time    depreciation  desired attention goal  Error Occurance  \
# 0           0.019266                     1.0              0.0
# 0.0625      0.019379                     NaN              0.0
# 0.125       0.019483                     NaN              0.0
# 0.1875      0.019580                     NaN              0.0
# 0.25        0.019668                     NaN              0.0
#
# Time    exogenous shock  ...  pressure from manager  Safety threshold  \
# 0                   0.0  ...                   10.0               0.5
# 0.0625              0.0  ...                    NaN               NaN
# 0.125               0.0  ...                    NaN               NaN
# 0.1875              0.0  ...                    NaN               NaN
# 0.25                0.0  ...                    NaN               NaN
#
# Time    SAVEPER  seed  SWTICH  T to depreciate  T to gain experience  \
# 0        0.0625   1.0     1.0              5.0                  10.0
# 0.0625   0.0625   NaN     NaN              NaN                   NaN
# 0.125    0.0625   NaN     NaN              NaN                   NaN
# 0.1875   0.0625   NaN     NaN              NaN                   NaN
# 0.25     0.0625   NaN     NaN              NaN                   NaN
#
# Time    T to grow attention  T to lose attention  TIME STEP
# 0                       1.0                 10.0     0.0625
# 0.0625                  NaN                  NaN        NaN
# 0.125                   NaN                  NaN        NaN
# 0.1875                  NaN                  NaN        NaN
# 0.25                    NaN                  NaN        NaN
#
# [5 rows x 29 columns]

# %%
plt.rc('font', family='Times New Roman')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_pulse_high['exogenous shock'], ax=ax, label='high')
sns.lineplot(data=df_pulse_med['exogenous shock'], ax=ax, label='medium',linestyle='--' )
sns.lineplot(data=df_pulse_low['exogenous shock'], ax=ax, label='low', linestyle=':')

# Set the legend
ax.legend()
ax.set_title('exogenous shock')

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('exogenous shock')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_pulse_high['Attention Resource'], ax=ax, label='Critical Impact Error' )
sns.lineplot(data=df_pulse_med['Attention Resource'], ax=ax, label='Significant Impact Error',linestyle='--' )
sns.lineplot(data=df_pulse_low['Attention Resource'], ax=ax, label='Moderate Impact Error', linestyle=':')

# Set the legend
ax.legend(fontsize = 10)
ax.set_title('Response to Impact of Serious Error to Attention Resource', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
fig.savefig('Images/Pluse_Attention.png')

# %%
# Create a figure and a set of subplots

plt.rc('font', family='Arial')
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_pulse_high['Organization knowledge'], ax=ax, label='Critical Impact Error' )
sns.lineplot(data=df_pulse_med['Organization knowledge'], ax=ax, label='Significant Impact Error',linestyle='--' )
sns.lineplot(data=df_pulse_low['Organization knowledge'], ax=ax, label='Moderate Impact Error', linestyle=':')

# Set the legend
ax.legend(fontsize = 10)
ax.set_title('Response to Impact of Serious Error to Organizational Knowledge', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Organization knowledge')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
fig.savefig('Images/Pluse_Knowledge.png')

# %% [markdown]
# # Tipping Point dynamics
#
# Phase plot

# %%
import pysd 
import pandas as pd
import netCDF4
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
model = pysd.read_vensim("../Experiment/safety focus_v9(Experiment).mdl")
stocks = model.run()
# model.doc

# %%
plt.rc('font', family='Arial')
fig, ax = plt.subplots()
stocks["Attention Resource"].plot()
stocks["Organization knowledge"].plot()
plt.title("Firm's Response to Serious Error at Month 20")
plt.ylabel("Attention Resource and Organization knowledge") 
plt.legend()
plt.xlabel("Month")


ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# plt.grid()
plt.show()

# %%
stocks
# Out:
#           FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  change in knowledge  \
# 0.0000           100             0   0.0625     0.0625            -0.028931
# 0.0625           100             0   0.0625     0.0625            -0.030176
# 0.1250           100             0   0.0625     0.0625            -0.031399
# 0.1875           100             0   0.0625     0.0625            -0.032599
# 0.2500           100             0   0.0625     0.0625            -0.033776
# ...              ...           ...      ...        ...                  ...
# 99.7500          100             0   0.0625     0.0625            -0.000014
# 99.8125          100             0   0.0625     0.0625            -0.000014
# 99.8750          100             0   0.0625     0.0625            -0.000014
# 99.9375          100             0   0.0625     0.0625            -0.000014
# 100.0000         100             0   0.0625     0.0625            -0.000014
#
#           change in attention  exogenous shock  Error Occurance  SWTICH  \
# 0.0000              -0.051720              0.0              0.0       1
# 0.0625              -0.051397              0.0              0.0       1
# 0.1250              -0.051075              0.0              0.0       1
# 0.1875              -0.050756              0.0              0.0       1
# 0.2500              -0.050439              0.0              0.0       1
# ...                       ...              ...              ...     ...
# 99.7500             -0.000097              0.0              0.0       1
# 99.8125             -0.000096              0.0              0.0       1
# 99.8750             -0.000095              0.0              0.0       1
# 99.9375             -0.000095              0.0              0.0       1
# 100.0000            -0.000094              0.0              0.0       1
#
#           Implied safety performance  ...  attention capability  \
# 0.0000                      0.687549  ...                    10
# 0.0625                      0.685741  ...                    10
# 0.1250                      0.683855  ...                    10
# 0.1875                      0.681893  ...                    10
# 0.2500                      0.679855  ...                    10
# ...                              ...  ...                   ...
# 99.7500                     0.006829  ...                    10
# 99.8125                     0.006828  ...                    10
# 99.8750                     0.006827  ...                    10
# 99.9375                     0.006827  ...                    10
# 100.0000                    0.006826  ...                    10
#
#           desired attention goal  initial focus  initial state  \
# 0.0000                         1       0.574914       0.614266
# 0.0625                         1       0.574914       0.614266
# 0.1250                         1       0.574914       0.614266
# 0.1875                         1       0.574914       0.614266
# 0.2500                         1       0.574914       0.614266
# ...                          ...            ...            ...
# 99.7500                        1       0.574914       0.614266
# 99.8125                        1       0.574914       0.614266
# 99.8750                        1       0.574914       0.614266
# 99.9375                        1       0.574914       0.614266
# 100.0000                       1       0.574914       0.614266
#
#           pressure from manager  Attention Resource  Safety threshold  seed  \
# 0.0000                       10            0.517199               0.5     1
# 0.0625                       10            0.513967               0.5     1
# 0.1250                       10            0.510755               0.5     1
# 0.1875                       10            0.507562               0.5     1
# 0.2500                       10            0.504390               0.5     1
# ...                         ...                 ...               ...   ...
# 99.7500                      10            0.000966               0.5     1
# 99.8125                      10            0.000960               0.5     1
# 99.8750                      10            0.000954               0.5     1
# 99.9375                      10            0.000948               0.5     1
# 100.0000                     10            0.000942               0.5     1
#
#           Attention erosion  T to lose attention
# 0.0000             0.051720                   10
# 0.0625             0.051397                   10
# 0.1250             0.051075                   10
# 0.1875             0.050756                   10
# 0.2500             0.050439                   10
# ...                     ...                  ...
# 99.7500            0.000097                   10
# 99.8125            0.000096                   10
# 99.8750            0.000095                   10
# 99.9375            0.000095                   10
# 100.0000           0.000094                   10
#
# [1601 rows x 31 columns]

# %%
# stocks = model.run()
stocks["exogenous shock"].plot()
# plt.title("Attention Resource")
# plt.ylabel("Degrees F")
plt.xlabel("Month")
plt.grid()

# %%
attention_resource = np.linspace(0,3,20)
organizational_knowledge = np.linspace(0,3, 20)


apv, okv = np.meshgrid(attention_resource, organizational_knowledge)

def derivatives(ar, ok):
    ret  = model.run(params={'attention_resource': ar, 'organization_knowledge': ok}, 
                     return_timestamps=[0, 1], 
                     return_columns=['change_in_attention', 'change_in_knowledge'])
    # print(ret)
    
    return tuple(ret.loc[0].values)

derivatives(0,1)
# Out:
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# (0.0, -0.19866142981514304)

# %%
vderivatives = np.vectorize(derivatives)

darv, dokv = vderivatives(apv, okv)
(darv == okv).all()
# Out:
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# ...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# False

# %%
plt.figure(figsize=(5,5))
# plt.quiver(apv, okv, darv, dokv, color='r', alpha=.75)
plt.streamplot(apv, okv, darv, dokv, color='b')

plt.box('off')
# plt.xlim(0,10)
plt.xlabel('Attention Resource')
plt.ylabel('Organization Knowledge')

plt.title('Phase potrait with one shock')
plt.savefig('Images/Streamplot_one_shock.png')

# %%
model = pysd.read_vensim("../Experiment/safety focus_v9(Experiment).mdl")

# %%
run1 = model.run(params={'SWTICH': 0, 'Safety threshold':1})
                           
# run1

plt.rc('font', family='Arial')
fig, ax = plt.subplots()

# Plot each column
run1["Attention Resource"].plot(ax = ax)
run1["Organization knowledge"].plot(ax=ax)

ax2 = ax.twinx()
# ax2.set_ylim([0, 0.1])
run1['Chance of Errors'].plot(ax=ax2, color='green')

# Set the legend
ax.legend(fontsize = 10)
ax.set_title('Response to Impact of Serious Error to Organizational Knowledge', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
# ax.set_ylabel('Organization knowledge')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph


# Set the y-axis label for the secondary axis
ax2.set_ylabel('Your Y Axis Label')

plt.legend(['Attention Resource', 'Organization knowledge','Chance of Errors'], loc='upper left')

# %%
run2 = model.run(params={'SWTICH': 0, 'Safety threshold':0.1})
                           
run2
run2["Attention Resource"].plot()
run2["Organization knowledge"].plot()
# Out:
# <Axes: >

# %%
attention_resource = np.linspace(-2,2,20)
organizational_knowledge = np.linspace(-1,1, 20)


apv, okv = np.meshgrid(attention_resource, organizational_knowledge)

def derivatives(ar, ok):
    ret  = model.run(params={'attention_resource': ar, 'organization_knowledge': ok}, 
                     return_timestamps=[0, 1], 
                     return_columns=['change_in_attention', 'change_in_knowledge'])
    # print(ret)
    
    return tuple(ret.loc[0].values)

derivatives(0,1)
# Out:
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# (0.0, -0.19866142981514304)

# %%
vderivatives = np.vectorize(derivatives)

darv, dokv = vderivatives(apv, okv)
(darv == okv).all()

# %%
plt.figure(figsize=(5,5))
# plt.quiver(apv, okv, darv, dokv, color='r', alpha=.75)
plt.streamplot(apv, okv, darv, dokv, color='b')

plt.box('off')
# plt.xlim(0,10)
plt.xlabel('Attention Resource')
plt.ylabel('Organization Knowledge')
# Out:
# Text(0, 0.5, 'Organization Knowledge')

# %% [markdown]
# # Damped oscialltion

# %%
model = pysd.read_vensim("../Experiment/safety focus_v10(Experiment).mdl")

my_run = model.run()

# %%
# my_run = model.run(params={'Safety threshold':0.1,
#                           'pressure from manager':60, 
#                           'desired attention goal':1,
#                           'gamma':0.1,
#                           'seed':20})



plt.rc('font', family='Arial')
fig, ax = plt.subplots()
my_run['Attention Resource'].plot(ax = ax)  
my_run['Organization knowledge'].plot()

# ax2 = ax.twinx()
# ax2.set_ylim([0, 0.1])
# my_run['Chance of Errors'].plot(ax=ax2, color='green')


plt.title("Firm's Response to Serious Error by chance of errors")
plt.ylabel("Attention Resource and Organization knowledge") 
plt.legend()
plt.xlabel("Month")


ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

plt.ylim(0.4,0.8)
# plt.grid()
plt.show()

# %%
my_run
# Out:
#           FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  Attention growth  \
# 0.0000           100             0   0.0625     0.0625          0.172470
# 0.0625           100             0   0.0625     0.0625          0.156620
# 0.1250           100             0   0.0625     0.0625          0.142116
# 0.1875           100             0   0.0625     0.0625          0.128879
# 0.2500           100             0   0.0625     0.0625          0.116826
# ...              ...           ...      ...        ...               ...
# 99.7500          100             0   0.0625     0.0625          0.052102
# 99.8125          100             0   0.0625     0.0625          0.052102
# 99.8750          100             0   0.0625     0.0625          0.052102
# 99.9375          100             0   0.0625     0.0625          0.052102
# 100.0000         100             0   0.0625     0.0625          0.052102
#
#           change in knowledge  change in attention  \
# 0.0000           3.647693e-02         1.028518e-01
# 0.0625           3.692702e-02         8.635870e-02
# 0.1250           3.724034e-02         7.131484e-02
# 0.1875           3.744001e-02         5.763228e-02
# 0.2500           3.754458e-02         4.521930e-02
# ...                       ...                  ...
# 99.7500          1.888784e-08        -3.712361e-08
# 99.8125          1.819610e-08        -3.950543e-08
# 99.8750          1.747187e-08        -4.175119e-08
# 99.9375          1.671746e-08        -4.385774e-08
# 100.0000         1.593521e-08        -4.582233e-08
#
#           Implied safety performance  Chance of Errors  Attention on Safety  \
# 0.0000                      0.511960          0.035480             0.876730
# 0.0625                      0.514240          0.032915             0.883510
# 0.1250                      0.516548          0.030419             0.888951
# 0.1875                      0.518876          0.028014             0.893276
# 0.2500                      0.521216          0.025716             0.896661
# ...                              ...               ...                  ...
# 99.7500                     0.552361          0.006799             0.552361
# 99.8125                     0.552361          0.006799             0.552361
# 99.8750                     0.552361          0.006799             0.552361
# 99.9375                     0.552361          0.006799             0.552361
# 100.0000                    0.552361          0.006799             0.552361
#
#           ...  attention capability  desired attention goal  initial focus  \
# 0.0000    ...                    10                       1       0.580327
# 0.0625    ...                    10                       1       0.580327
# 0.1250    ...                    10                       1       0.580327
# 0.1875    ...                    10                       1       0.580327
# 0.2500    ...                    10                       1       0.580327
# ...       ...                   ...                     ...            ...
# 99.7500   ...                    10                       1       0.580327
# 99.8125   ...                    10                       1       0.580327
# 99.8750   ...                    10                       1       0.580327
# 99.9375   ...                    10                       1       0.580327
# 100.0000  ...                    10                       1       0.580327
#
#           initial state  pressure from manager  Attention Resource  \
# 0.0000         0.660127                     50            0.696182
# 0.0625         0.660127                     50            0.702610
# 0.1250         0.660127                     50            0.708008
# 0.1875         0.660127                     50            0.712465
# 0.2500         0.660127                     50            0.716067
# ...                 ...                    ...                 ...
# 99.7500        0.660127                     50            0.521022
# 99.8125        0.660127                     50            0.521022
# 99.8750        0.660127                     50            0.521022
# 99.9375        0.660127                     50            0.521022
# 100.0000       0.660127                     50            0.521022
#
#           Safety threshold  seed  Attention erosion  T to lose attention
# 0.0000                 0.5     1           0.069618                   10
# 0.0625                 0.5     1           0.070261                   10
# 0.1250                 0.5     1           0.070801                   10
# 0.1875                 0.5     1           0.071246                   10
# 0.2500                 0.5     1           0.071607                   10
# ...                    ...   ...                ...                  ...
# 99.7500                0.5     1           0.052102                   10
# 99.8125                0.5     1           0.052102                   10
# 99.8750                0.5     1           0.052102                   10
# 99.9375                0.5     1           0.052102                   10
# 100.0000               0.5     1           0.052102                   10
#
# [1601 rows x 28 columns]

# %%
plt.rc('font', family='Arial')
fig, ax = plt.subplots()

# ax2.set_ylim([0, 0.1])
my_run['Chance of Errors'].plot(ax=ax, color='green')


plt.title("Firms's Chance of errors")
plt.ylabel("Probability of errors") 
plt.legend()
plt.xlabel("Month")


ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph
 # plt.grid()
plt.show()

# %%
attention_resource = np.linspace(0,4,20)
organizational_knowledge = np.linspace(0,4, 20)


apv, okv = np.meshgrid(attention_resource, organizational_knowledge)

def derivatives(ar, ok):
    ret  = model.run(params={'attention_resource': ar, 'organization_knowledge': ok}, 
                     return_timestamps=[0, 1], 
                     return_columns=['change_in_attention', 'change_in_knowledge'])
    # print(ret)
    
    return tuple(ret.loc[0].values)

derivatives(0,1)
# Out:
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'attention_resource' with params...
#   self.set_components(params)
# /Users/Georgia 1/Library/Mobile Documents/com~apple~CloudDocs/Georgia's Files/Research Papers /Adopt to auto paper/Python code/OrganizationOscillation/env/lib/python3.11/site-packages/pysd/py_backend/model.py:1431: UserWarning: Replacing the equation of stock 'organization_knowledge' with params...
#   self.set_components(params)
# (2.2220802975425614e-11, -0.19866142981514304)

# %%
# imoprt warnings 
vderivatives = np.vectorize(derivatives)

darv, dokv = vderivatives(apv, okv)
(darv == okv).all()

# dont's show warning sign error 
# warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(5,5))
# plt.quiver(apv, okv, darv, dokv, color='r', alpha=.75)
plt.streamplot(apv, okv, darv, dokv, color='b')

plt.box('off')

plt.title('Phase potrait with chance of errors')
plt.xlabel('Attention Resource')
plt.ylabel('Organization Knowledge')
plt.show()

plt.savefig('Images/Streamplot_case2.png')

# %% [markdown]
# # Noise

# %% [markdown]
# ## Somehow the white noise is not loading properlly,,,

# %%
model = pysd.read_vensim("../Experiment/safety focus_v11(Noise).mdl")

# %%
model.doc
# Out:
#                      Real Name                     Py Name Subscripts  Units  \
# 0           Attention Resource          attention_resource       None   None
# 1            Attention erosion           attention_erosion       None   None
# 2             Attention growth            attention_growth       None   None
# 3          Attention on Safety         attention_on_safety       None   None
# 4                   Auto noise                  auto_noise       None   None
# 5             Chance of Errors            chance_of_errors       None   None
# 6              Error Occurance             error_occurance       None   None
# 7                   FINAL TIME                  final_time       None  Month
# 8                 INITIAL TIME                initial_time       None  Month
# 9   Implied safety performance  implied_safety_performance       None   None
# 10  Normal Attention on Safety  normal_attention_on_safety       None   None
# 11      Organization knowledge      organization_knowledge       None   None
# 12                     SAVEPER                     saveper       None  Month
# 13            Safety threshold            safety_threshold       None   None
# 14             T to depreciate             t_to_depreciate       None   None
# 15        T to gain experience        t_to_gain_experience       None   None
# 16         T to grow attention         t_to_grow_attention       None   None
# 17         T to lose attention         t_to_lose_attention       None   None
# 18                   TIME STEP                   time_step       None  Month
# 19                        Time                        time       None   None
# 20        attention capability        attention_capability       None   None
# 21            correlation time            correlation_time       None   None
# 22                depreciation                depreciation       None   None
# 23      desired attention goal      desired_attention_goal       None   None
# 24                  experience                  experience       None   None
# 25                       gamma                       gamma       None   None
# 26               initial focus               initial_focus       None   None
# 27               initial state               initial_state       None   None
# 28                        mean                        mean       None   None
# 29                  pink noise                  pink_noise       None   None
# 30       pressure from manager       pressure_from_manager       None   None
# 31                        seed                        seed       None   None
# 32                       seed2                       seed2       None   None
# 33                         std                         std       None   None
# 34         updating pink noise         updating_pink_noise       None   None
# 35                 white noise                 white_noise       None   None
#
#                Limits       Type Subtype  \
# 0          (nan, nan)   Stateful   Integ
# 1          (nan, nan)  Auxiliary  Normal
# 2          (nan, nan)  Auxiliary  Normal
# 3          (nan, nan)  Auxiliary  Normal
# 4          (nan, nan)   Stateful   Integ
# 5          (nan, nan)  Auxiliary  Normal
# 6          (nan, nan)  Auxiliary  Normal
# 7          (nan, nan)   Constant  Normal
# 8          (nan, nan)   Constant  Normal
# 9          (nan, nan)  Auxiliary  Normal
# 10   (0.0, 1.0, 0.02)   Constant  Normal
# 11         (nan, nan)   Stateful   Integ
# 12         (0.0, nan)  Auxiliary  Normal
# 13   (0.0, 1.0, 0.02)   Constant  Normal
# 14   (1.0, 50.0, 1.0)   Constant  Normal
# 15   (1.0, 50.0, 0.5)   Constant  Normal
# 16    (1.0, 5.0, 1.0)   Constant  Normal
# 17   (1.0, 50.0, 0.5)   Constant  Normal
# 18         (0.0, nan)   Constant  Normal
# 19         (nan, nan)       None    None
# 20   (0.5, 30.0, 0.2)   Constant  Normal
# 21       (1.0, 100.0)   Constant  Normal
# 22         (nan, nan)  Auxiliary  Normal
# 23   (0.5, 1.0, 0.02)   Constant  Normal
# 24         (nan, nan)  Auxiliary  Normal
# 25         (nan, nan)   Constant  Normal
# 26         (nan, nan)  Auxiliary  Normal
# 27         (nan, nan)  Auxiliary  Normal
# 28         (nan, nan)   Constant  Normal
# 29         (nan, nan)  Auxiliary  Normal
# 30   (0.0, 20.0, 1.0)   Constant  Normal
# 31  (0.0, 100.0, 1.0)   Constant  Normal
# 32         (nan, nan)   Constant  Normal
# 33         (nan, nan)   Constant  Normal
# 34         (nan, nan)  Auxiliary  Normal
# 35         (nan, nan)  Auxiliary  Normal
#
#                                               Comment
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   IF THEN ELSE( INTEGER(Time)=Time, IF THEN ELSE...
# 7                  The final time for the simulation.
# 8                The initial time for the simulation.
# 9                                                None
# 10                                               None
# 11                                               None
# 12         The frequency with which output is stored.
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                  The time step for the simulation.
# 19                         Current time of the model.
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None

# %%
condition1 = {
   
    'mean': 0.15, 
    'std': 0.05,
    'seed':50,
    'correlation time' :10
    }

noise_1 = model.run(params=condition1)

# %%
noise_1 = model.run()

# %%
noise_1
#print all columns 
pd.options.display.max_columns = None
noise_1
# Out:
#           FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  Error Occurance  mean  \
# 0.0000           100             0   0.0625     0.0625              1.0  0.15
# 0.0625           100             0   0.0625     0.0625              0.0  0.15
# 0.1250           100             0   0.0625     0.0625              0.0  0.15
# 0.1875           100             0   0.0625     0.0625              0.0  0.15
# 0.2500           100             0   0.0625     0.0625              0.0  0.15
# ...              ...           ...      ...        ...              ...   ...
# 99.7500          100             0   0.0625     0.0625              0.0  0.15
# 99.8125          100             0   0.0625     0.0625              0.0  0.15
# 99.8750          100             0   0.0625     0.0625              0.0  0.15
# 99.9375          100             0   0.0625     0.0625              0.0  0.15
# 100.0000         100             0   0.0625     0.0625              0.0  0.15
#
#           seed2   std  white noise  correlation time  Auto noise  \
# 0.0000        1  0.05     0.250955                10    0.000000
# 0.0625        1  0.05     0.250955                10    0.001568
# 0.1250        1  0.05     0.250955                10    0.003127
# 0.1875        1  0.05     0.250955                10    0.004676
# 0.2500        1  0.05     0.250955                10    0.006215
# ...         ...   ...          ...               ...         ...
# 99.7500       1  0.05     0.250955                10    0.250943
# 99.8125       1  0.05     0.250955                10    0.250943
# 99.8750       1  0.05     0.250955                10    0.250943
# 99.9375       1  0.05     0.250955                10    0.250944
# 100.0000      1  0.05     0.250955                10    0.250944
#
#           updating pink noise  pink noise  Implied safety performance  \
# 0.0000               0.025095    0.000000                    0.638680
# 0.0625               0.024939    0.001568                    0.639758
# 0.1250               0.024783    0.003127                    0.641966
# 0.1875               0.024628    0.004676                    0.644157
# 0.2500               0.024474    0.006215                    0.646332
# ...                       ...         ...                         ...
# 99.7500              0.000001    0.250943                    0.006699
# 99.8125              0.000001    0.250943                    0.006699
# 99.8750              0.000001    0.250943                    0.006699
# 99.9375              0.000001    0.250944                    0.006699
# 100.0000             0.000001    0.250944                    0.006699
#
#           Chance of Errors  Attention on Safety  gamma  depreciation  \
# 0.0000            0.019992             0.811015    0.1  0.000000e+00
# 0.0625            0.019820             0.993033    0.1  0.000000e+00
# 0.1250            0.019472             0.992589    0.1  0.000000e+00
# 0.1875            0.019130             0.992120    0.1  0.000000e+00
# 0.2500            0.018796             0.991625    0.1  0.000000e+00
# ...                    ...                  ...    ...           ...
# 99.7500           0.099285             0.006696    0.1  6.052938e-07
# 99.8125           0.099285             0.006696    0.1  6.014867e-07
# 99.8750           0.099285             0.006696    0.1  5.977037e-07
# 99.9375           0.099285             0.006696    0.1  5.939446e-07
# 100.0000          0.099285             0.006696    0.1  5.902093e-07
#
#           Organization knowledge  Attention growth  T to depreciate  \
# 0.0000                  0.638680          5.669407                5
# 0.0625                  0.639758          0.000000                5
# 0.1250                  0.641966          0.000000                5
# 0.1875                  0.644157          0.000000                5
# 0.2500                  0.646332          0.000000                5
# ...                          ...               ...              ...
# 99.7500                 0.006699          0.000000                5
# 99.8125                 0.006699          0.000000                5
# 99.8750                 0.006699          0.000000                5
# 99.9375                 0.006699          0.000000                5
# 100.0000                0.006699          0.000000                5
#
#           experience  T to grow attention  Normal Attention on Safety  \
# 0.0000      0.017233                    1                         0.5
# 0.0625      0.035328                    1                         0.5
# 0.1250      0.035062                    1                         0.5
# 0.1875      0.034796                    1                         0.5
# 0.2500      0.034529                    1                         0.5
# ...              ...                  ...                         ...
# 99.7500     0.000000                    1                         0.5
# 99.8125     0.000000                    1                         0.5
# 99.8750     0.000000                    1                         0.5
# 99.9375     0.000000                    1                         0.5
# 100.0000    0.000000                    1                         0.5
#
#           T to gain experience  attention capability  desired attention goal  \
# 0.0000                      10                    10                       1
# 0.0625                      10                    10                       1
# 0.1250                      10                    10                       1
# 0.1875                      10                    10                       1
# 0.2500                      10                    10                       1
# ...                        ...                   ...                     ...
# 99.7500                     10                    10                       1
# 99.8125                     10                    10                       1
# 99.8750                     10                    10                       1
# 99.9375                     10                    10                       1
# 100.0000                    10                    10                       1
#
#           initial focus  initial state  pressure from manager  \
# 0.0000         0.544288       0.608852                     10
# 0.0625         0.544288       0.608852                     10
# 0.1250         0.544288       0.608852                     10
# 0.1875         0.544288       0.608852                     10
# 0.2500         0.544288       0.608852                     10
# ...                 ...            ...                    ...
# 99.7500        0.544288       0.608852                     10
# 99.8125        0.544288       0.608852                     10
# 99.8750        0.544288       0.608852                     10
# 99.9375        0.544288       0.608852                     10
# 100.0000       0.544288       0.608852                     10
#
#           Attention Resource  Safety threshold  seed  Attention erosion  \
# 0.0000              0.645662               0.5    50           0.064566
# 0.0625              0.995965               0.5    50           0.099596
# 0.1250              0.989740               0.5    50           0.098974
# 0.1875              0.983554               0.5    50           0.098355
# 0.2500              0.977407               0.5    50           0.097741
# ...                      ...               ...   ...                ...
# 99.7500             0.000045               0.5    50           0.000005
# 99.8125             0.000045               0.5    50           0.000004
# 99.8750             0.000045               0.5    50           0.000004
# 99.9375             0.000044               0.5    50           0.000004
# 100.0000            0.000044               0.5    50           0.000004
#
#           T to lose attention
# 0.0000                     10
# 0.0625                     10
# 0.1250                     10
# 0.1875                     10
# 0.2500                     10
# ...                       ...
# 99.7500                    10
# 99.8125                    10
# 99.8750                    10
# 99.9375                    10
# 100.0000                   10
#
# [1601 rows x 35 columns]

# %%
noise_1['white noise'].plot()
# Out:
# <Axes: >

# %%
plt.rc('font', family='Arial')
fig, ax = plt.subplots()
noise_1['Attention Resource'].plot(ax = ax)  
noise_1['Organization knowledge'].plot(ax = ax)

# ax2 = ax.twinx()
# ax2.set_ylim([0, 0.1])
# my_run['Chance of Errors'].plot(ax=ax2, color='green')


plt.title("Firm's Response to Serious Error by chance of errors")
plt.ylabel("Attention Resource and Organization knowledge") 
plt.legend()
plt.xlabel("Month")


ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# plt.grid()
plt.show()

# %% [markdown]
# # Get the result directly from excel sheet

# %%
df_noise1 = pd.read_excel('../Experiment/noise1.xlsx')

df_noise1 = df_noise1.transpose()
# Set the first row as column names
df_noise1.columns = df_noise1.iloc[0]

# Drop the first row
df_noise1 = df_noise1.drop(df_noise1.index[0])

df_noise1 = df_noise1.astype(float)
df_noise1.head()
# Out:
# Time    attention capability  Attention erosion  Attention growth  \
# 0                       10.0           0.029105         11.343267
# 0.0625                   NaN           0.099818          0.000000
# 0.125                    NaN           0.099194          0.000000
# 0.1875                   NaN           0.098574          0.000000
# 0.25                     NaN           0.097958          0.000000
#
# Time    Attention on Safety  Attention Resource  Auto noise  Chance of Errors  \
# 0                  0.110117            0.291046    0.000000          0.048389
# 0.0625             0.993185            0.998181    0.003504          0.048690
# 0.125              0.992750            0.991942    0.002644          0.047460
# 0.1875             0.992289            0.985743   -0.005534          0.046243
# 0.25               0.991804            0.979582   -0.005728          0.045037
#
# Time    correlation time  depreciation  desired attention goal  ...  seed  \
# 0                   10.0      0.019266                     1.0  ...   1.0
# 0.0625               NaN      0.000000                     NaN  ...   NaN
# 0.125                NaN      0.000000                     NaN  ...   NaN
# 0.1875               NaN      0.000000                     NaN  ...   NaN
# 0.25                 NaN      0.000000                     NaN  ...   NaN
#
# Time    seed2   std  T to depreciate  T to gain experience  \
# 0        20.0  0.05              5.0                  10.0
# 0.0625    NaN   NaN              NaN                   NaN
# 0.125     NaN   NaN              NaN                   NaN
# 0.1875    NaN   NaN              NaN                   NaN
# 0.25      NaN   NaN              NaN                   NaN
#
# Time    T to grow attention  T to lose attention  TIME STEP  \
# 0                       1.0                 10.0     0.0625
# 0.0625                  NaN                  NaN        NaN
# 0.125                   NaN                  NaN        NaN
# 0.1875                  NaN                  NaN        NaN
# 0.25                    NaN                  NaN        NaN
#
# Time    updating pink noise  white noise
# 0                  0.056059     0.560588
# 0.0625            -0.013762    -0.134117
# 0.125             -0.130848    -1.305839
# 0.1875            -0.003092    -0.036451
# 0.25               0.099430     0.988573
#
# [5 rows x 35 columns]

# %%
df_noise2 = pd.read_excel('../Experiment/noise2.xlsx')

df_noise2 = df_noise2.transpose()
# Set the first row as column names
df_noise2.columns = df_noise2.iloc[0]

# Drop the first row
df_noise2 = df_noise2.drop(df_noise2.index[0])

df_noise2 = df_noise2.astype(float)
df_noise2.head()
# Out:
# Time    attention capability  Attention erosion  Attention growth  \
# 0                       10.0           0.029105         11.343267
# 0.0625                   NaN           0.099818          0.000000
# 0.125                    NaN           0.099194          0.000000
# 0.1875                   NaN           0.098574          0.000000
# 0.25                     NaN           0.097958          0.000000
#
# Time    Attention on Safety  Attention Resource  Auto noise  Chance of Errors  \
# 0                  0.110117            0.291046    0.000000          0.048389
# 0.0625             0.993185            0.998181    0.011202          0.048690
# 0.125              0.992750            0.991942    0.004967          0.047460
# 0.1875             0.992289            0.985743   -0.030523          0.046243
# 0.25               0.991804            0.979582   -0.034056          0.045037
#
# Time    correlation time  depreciation  desired attention goal  ...  seed  \
# 0                   10.0      0.019266                     1.0  ...   1.0
# 0.0625               NaN      0.000000                     NaN  ...   NaN
# 0.125                NaN      0.000000                     NaN  ...   NaN
# 0.1875               NaN      0.000000                     NaN  ...   NaN
# 0.25                 NaN      0.000000                     NaN  ...   NaN
#
# Time    seed2  std  T to depreciate  T to gain experience  \
# 0        20.0  0.2              5.0                  10.0
# 0.0625    NaN  NaN              NaN                   NaN
# 0.125     NaN  NaN              NaN                   NaN
# 0.1875    NaN  NaN              NaN                   NaN
# 0.25      NaN  NaN              NaN                   NaN
#
# Time    T to grow attention  T to lose attention  TIME STEP  \
# 0                       1.0                 10.0     0.0625
# 0.0625                  NaN                  NaN        NaN
# 0.125                   NaN                  NaN        NaN
# 0.1875                  NaN                  NaN        NaN
# 0.25                    NaN                  NaN        NaN
#
# Time    updating pink noise  white noise
# 0                  0.179235     1.792350
# 0.0625            -0.099767    -0.986469
# 0.125             -0.567832    -5.673358
# 0.1875            -0.056528    -0.595805
# 0.25               0.353835     3.504291
#
# [5 rows x 35 columns]

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise1['pink noise'], ax=ax, label='std = 0.05' )
sns.lineplot(data=df_noise2['pink noise'], ax=ax, label='std = 0.2',linestyle='--')

# Add arrows that point to the lines
ax.annotate('std = 0.2', xy=(26, 0.4), xytext=(7, 0.4), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
ax.annotate('std = 0.05', xy=(40, 0.15), xytext=(40,0), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)


# Set the legend
ax.get_legend().remove()
ax.set_title('Environmental volatillity (mean = 0.15)', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
fig.savefig('Images/Noise.png')

# %%
df_noise3 = pd.read_excel('../Experiment/noise3.xlsx')

df_noise3 = df_noise3.transpose()
# Set the first row as column names
df_noise3.columns = df_noise3.iloc[0]

# Drop the first row
df_noise3 = df_noise3.drop(df_noise3.index[0])

df_noise3 = df_noise3.astype(float)
df_noise3.head()
# Out:
# Time    attention capability  Attention erosion  Attention growth  \
# 0                       10.0           0.029105         11.343267
# 0.0625                   NaN           0.099818          0.000000
# 0.125                    NaN           0.099194          0.000000
# 0.1875                   NaN           0.098574          0.000000
# 0.25                     NaN           0.097958          0.000000
#
# Time    Attention on Safety  Attention Resource  Auto noise  Chance of Errors  \
# 0                  0.110117            0.291046    0.000000          0.099736
# 0.0625             0.993185            0.998181    0.003504          0.099739
# 0.125              0.992750            0.991942    0.002644          0.099726
# 0.1875             0.992289            0.985743   -0.005534          0.099713
# 0.25               0.991804            0.979582   -0.005728          0.099698
#
# Time    correlation time  depreciation  desired attention goal  ...  seed  \
# 0                   10.0      0.019266                     1.0  ...   1.0
# 0.0625               NaN      0.000000                     NaN  ...   NaN
# 0.125                NaN      0.000000                     NaN  ...   NaN
# 0.1875               NaN      0.000000                     NaN  ...   NaN
# 0.25                 NaN      0.000000                     NaN  ...   NaN
#
# Time    seed2   std  T to depreciate  T to gain experience  \
# 0        20.0  0.05              5.0                  10.0
# 0.0625    NaN   NaN              NaN                   NaN
# 0.125     NaN   NaN              NaN                   NaN
# 0.1875    NaN   NaN              NaN                   NaN
# 0.25      NaN   NaN              NaN                   NaN
#
# Time    T to grow attention  T to lose attention  TIME STEP  \
# 0                       1.0                 10.0     0.0625
# 0.0625                  NaN                  NaN        NaN
# 0.125                   NaN                  NaN        NaN
# 0.1875                  NaN                  NaN        NaN
# 0.25                    NaN                  NaN        NaN
#
# Time    updating pink noise  white noise
# 0                  0.056059     0.560588
# 0.0625            -0.013762    -0.134117
# 0.125             -0.130848    -1.305839
# 0.1875            -0.003092    -0.036451
# 0.25               0.099430     0.988573
#
# [5 rows x 35 columns]

# %%
df_noise4 = pd.read_excel('../Experiment/noise4.xlsx')

df_noise4 = df_noise4.transpose()
# Set the first row as column names
df_noise4.columns = df_noise4.iloc[0]

# Drop the first row
df_noise4 = df_noise4.drop(df_noise4.index[0])

df_noise4 = df_noise4.astype(float)
df_noise4.head()
# Out:
# Time    attention capability  Attention erosion  Attention growth  \
# 0                       10.0           0.029105         11.343267
# 0.0625                   NaN           0.099818          0.000000
# 0.125                    NaN           0.099194          0.000000
# 0.1875                   NaN           0.098574          0.000000
# 0.25                     NaN           0.097958          0.000000
#
# Time    Attention on Safety  Attention Resource  Auto noise  Chance of Errors  \
# 0                  0.110117            0.291046    0.000000          0.099736
# 0.0625             0.993185            0.998181    0.011202          0.099739
# 0.125              0.992750            0.991942    0.004967          0.099726
# 0.1875             0.992289            0.985743   -0.030523          0.099713
# 0.25               0.991804            0.979582   -0.034056          0.099698
#
# Time    correlation time  depreciation  desired attention goal  ...  seed  \
# 0                   10.0      0.019266                     1.0  ...   1.0
# 0.0625               NaN      0.000000                     NaN  ...   NaN
# 0.125                NaN      0.000000                     NaN  ...   NaN
# 0.1875               NaN      0.000000                     NaN  ...   NaN
# 0.25                 NaN      0.000000                     NaN  ...   NaN
#
# Time    seed2  std  T to depreciate  T to gain experience  \
# 0        20.0  0.2              5.0                  10.0
# 0.0625    NaN  NaN              NaN                   NaN
# 0.125     NaN  NaN              NaN                   NaN
# 0.1875    NaN  NaN              NaN                   NaN
# 0.25      NaN  NaN              NaN                   NaN
#
# Time    T to grow attention  T to lose attention  TIME STEP  \
# 0                       1.0                 10.0     0.0625
# 0.0625                  NaN                  NaN        NaN
# 0.125                   NaN                  NaN        NaN
# 0.1875                  NaN                  NaN        NaN
# 0.25                    NaN                  NaN        NaN
#
# Time    updating pink noise  white noise
# 0                  0.179235     1.792350
# 0.0625            -0.099767    -0.986469
# 0.125             -0.567832    -5.673358
# 0.1875            -0.056528    -0.595805
# 0.25               0.353835     3.504291
#
# [5 rows x 35 columns]

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise1['Attention Resource'], ax=ax, label='Safety Focused Firm' )
sns.lineplot(data=df_noise3['Attention Resource'], ax=ax, label='Profit Focused Firm',linestyle='--')


# Add arrows that point to the lines
ax.annotate('Profit Focused Firm', xy=(36, 0.5), xytext=(40, 0.6), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
ax.annotate('Safety Focused Firm', xy=(18, 0.2), xytext=(1,0), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)

# Set the legend
ax.get_legend().remove()
ax.set_title('Response to Noise (mean = 0.15,  standard deviation = 0.05) ', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph


# Show the plot
plt.show()
# Save the plot
fig.savefig('Images/Noisessmall_Attention.png')

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise1['Organization knowledge'], ax=ax, label='Safety Focused Firm' )
sns.lineplot(data=df_noise3['Organization knowledge'], ax=ax, label='Profit Focused Firm',linestyle='--')

# Add arrows that point to the lines
ax.annotate('Profit Focused Firm', xy=(20, 0.7), xytext=(30, 0.7), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
ax.annotate('Safety Focused Firm', xy=(17, 0.25), xytext=(0,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)


# Set the legend
ax.get_legend().remove()
ax.set_title('Response to Noise (mean = 0.15,  standard deviation = 0.05) ', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Organization knowledge')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
fig.savefig('Images/Noise_small_knowledge.png')

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise1['Chance of Errors'], ax=ax, label='Safety Focused Firm' )
sns.lineplot(data=df_noise3['Chance of Errors'], ax=ax, label='Profit Focused Firm',linestyle='--')

# Add arrows that point to the lines
ax.annotate('Safety Focused Firm', xy=(20, 0.02), xytext=(24, 0.01), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
ax.annotate('Profit Focused Firm', xy=(15, 0.085), xytext=(-0.1,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)


# Set the legend
ax.get_legend().remove()
ax.set_title('Response to Noise (mean = 0.15,  standard deviation = 0.05) ', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Probability of errors')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
fig.savefig('Images/Chance of errors_small_knowledge.png')

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise2['Attention Resource'], ax=ax, label='Safety Focused Firm' )
sns.lineplot(data=df_noise4['Attention Resource'], ax=ax, label='Profit Focused Firm',linestyle='--')


# Add arrows that point to the lines
ax.annotate('Profit Focused Firm', xy=(39, 0.5), xytext=(43, 0.6), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
ax.annotate('Safety Focused Firm', xy=(36, 0.3), xytext=(2,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)

# Set the legend
ax.get_legend().remove()
ax.set_title('Response to Noise (mean = 0.15,  standard deviation = 0.2) ', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph


# Show the plot
plt.show()
# Save the plot
fig.savefig('Images/Noiseslarge_Attention.png')

# %%
fig, ax = plt.subplots()

sns.lineplot(data=df_noise3['pink noise'], ax=ax, label='pink noise 3')
sns.lineplot(data=df_noise1['pink noise'], ax=ax, label='pink noise 1')
sns.lineplot(data=df_noise4['pink noise'], ax=ax, label='pink noise 4')
sns.lineplot(data=df_noise2['pink noise'], ax=ax, label='pink noise 2')
plt.show()

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise1['Chance of Errors'], ax=ax, label='Chance of Errors' )
sns.lineplot(data=df_noise1['Error Occurance'], ax=ax, label='Error Occurance')
sns.lineplot(data=df_noise3['pink noise'], ax=ax, label='pink noise')


# # Add arrows that point to the lines
# ax.annotate('Profit Focused Firm', xy=(20, 0.5), xytext=(33, 0.2), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
# ax.annotate('Safety Focused Firm', xy=(22, 0.2), xytext=(2,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)

# Set the legend
# ax.get_legend().remove()
ax.set_title('Safety focus firm, stable env', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph


# Show the plot
plt.show()

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise3['Chance of Errors'], ax=ax, label='Chance of Errors' )
sns.lineplot(data=df_noise3['Error Occurance'], ax=ax, label='Error Occurance')
sns.lineplot(data=df_noise3['pink noise'], ax=ax, label='pink noise')


# # Add arrows that point to the lines
# ax.annotate('Profit Focused Firm', xy=(20, 0.5), xytext=(33, 0.2), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
# ax.annotate('Safety Focused Firm', xy=(22, 0.2), xytext=(2,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)

# Set the legend
# ax.get_legend().remove()
ax.set_title('Profit focus firm, stable env', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph


# Show the plot
plt.show()

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise2['Organization knowledge'], ax=ax, label='Safety Focused Firm' )
sns.lineplot(data=df_noise4['Organization knowledge'], ax=ax, label='Profit Focused Firm',linestyle='--')

# Add arrows that point to the lines
ax.annotate('Profit Focused Firm', xy=(40, 0.7), xytext=(45, 0.8), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
ax.annotate('Safety Focused Firm', xy=(22, 0.35), xytext=(15,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)


# Set the legend
ax.get_legend().remove()
ax.set_title('Response to Noise (mean = 0.15,  standard deviation = 0.2) ', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Organization knowledge')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
fig.savefig('Images/Noise_large_knowledge.png')

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise4['Chance of Errors'], ax=ax, label='Chance of Errors' )
sns.lineplot(data=df_noise4['Error Occurance'], ax=ax, label='Error Occurance')
sns.lineplot(data=df_noise4['pink noise'], ax=ax, label='pink noise')


# # Add arrows that point to the lines
# ax.annotate('Profit Focused Firm', xy=(20, 0.5), xytext=(33, 0.2), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
# ax.annotate('Safety Focused Firm', xy=(22, 0.2), xytext=(2,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)

# Set the legend
# ax.get_legend().remove()
ax.set_title('Profit focus firm', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph


# Show the plot
plt.show()

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise2['Chance of Errors'], ax=ax, label='Chance of Errors' )
sns.lineplot(data=df_noise2['Error Occurance'], ax=ax, label='Error Occurance')
sns.lineplot(data=df_noise2['pink noise'], ax=ax, label='pink noise')

# # Add arrows that point to the lines
# ax.annotate('Profit Focused Firm', xy=(20, 0.5), xytext=(33, 0.2), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
# ax.annotate('Safety Focused Firm', xy=(22, 0.2), xytext=(2,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)

# Set the legend
# ax.get_legend().remove()
ax.set_title('Safety focus firm', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
# ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph


# Show the plot
plt.show()

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise2['Error Occurance'], ax=ax, label='Safety Focused Firm' )
sns.lineplot(data=df_noise4['Error Occurance'], ax=ax, label='Profit Focused Firm',linestyle='--')


# Add arrows that point to the lines
ax.annotate('Profit Focused Firm', xy=(20, 0.5), xytext=(33, 0.2), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
ax.annotate('Safety Focused Firm', xy=(22, 0.2), xytext=(2,0.1), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)

# Set the legend
ax.get_legend().remove()
ax.set_title('Response to Noise (mean = 0.15,  standard deviation = 0.2) ', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph


# Show the plot
plt.show()
# Save the plot
# fig.savefig('Images/Noiseslarge_Attention.png')

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise2['Chance of Errors'], ax=ax, label='Safety Focused Firm' )
sns.lineplot(data=df_noise4['Chance of Errors'], ax=ax, label='Profit Focused Firm',linestyle='--')

# Add arrows that point to the lines
ax.annotate('Safety Focused Firm', xy=(5, 0.015), xytext=(15, 0.02), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)
ax.annotate('Profit Focused Firm', xy=(11, 0.085), xytext=(18,0.08), arrowprops=dict(facecolor='black', lw=0.05), fontsize=10)


# Set the legend
# ax.get_legend().remove()
ax.set_title('Response to Noise (mean = 0.15,  standard deviation = 0.2) ', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Probability of errors')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
fig.savefig('Images/Chance of errors_large.png')

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise3['Organization knowledge'], ax=ax, label='3' )
sns.lineplot(data=df_noise4['Organization knowledge'], ax=ax, label='4')
sns.lineplot(data=df_noise1['Organization knowledge'], ax=ax, label='1')
sns.lineplot(data=df_noise2['Organization knowledge'], ax=ax, label='2')

# Set the legend
ax.legend(fontsize = 10)
ax.set_title('Response to Impact of Serious Error to Organization knowledge', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Organization knowledge')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise3['Attention Resource'], ax=ax, label='3' )
sns.lineplot(data=df_noise4['Attention Resource'], ax=ax, label='4')
sns.lineplot(data=df_noise1['Attention Resource'], ax=ax, label='1')
sns.lineplot(data=df_noise2['Attention Resource'], ax=ax, label='2')

# Set the legend
ax.legend(fontsize = 10)
ax.set_title('Response to Impact of Serious Error to Attention Resource', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
# fig.savefig('Images/Noise_Attention.png')

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise3['Error Occurance'], ax=ax, label='3' )
sns.lineplot(data=df_noise4['Error Occurance'], ax=ax, label='4')
sns.lineplot(data=df_noise1['Error Occurance'], ax=ax, label='1')
sns.lineplot(data=df_noise2['Error Occurance'], ax=ax, label='2')

# Set the legend
ax.legend(fontsize = 10)
ax.set_title('Response to Impact of Serious Error to Attention Resource', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
# fig.savefig('Images/Noise_Attention.png')

# %%
plt.rc('font', family='Arial')

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot each column
sns.lineplot(data=df_noise3['Chance of Errors'], ax=ax, label='3' )
sns.lineplot(data=df_noise4['Chance of Errors'], ax=ax, label='4')
sns.lineplot(data=df_noise1['Chance of Errors'], ax=ax, label='1')
sns.lineplot(data=df_noise2['Chance of Errors'], ax=ax, label='2')

# Set the legend
ax.legend(fontsize = 10)
ax.set_title('Chance of errors', fontsize=12)

# Set x and y axis titles
ax.set_xlabel('Time (Month)')
ax.set_ylabel('Attention Resource')

ax.xaxis.tick_top() # This moves the x-axis labels to the top
ax.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

ax2 = ax.twiny() # This creates a new set of axes with the same y-axis
ax2.xaxis.tick_top() # This moves the new x-axis labels to the top
ax2.set_xticklabels([]) # This removes the new x-axis labels
ax2.tick_params(axis='x', direction='in') # This moves the x-axis ticks inside the graph

# Show the plot
plt.show()
# Save the plot
# fig.savefig('Images/Noise_Attention.png')
